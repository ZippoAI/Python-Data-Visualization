# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = sns.load_dataset('tips')

df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Categorical Plot
#
# ## What is a Categorical Plot?
# A **categorical plot** is used to visualize **categorical data** (non-numeric labels) against
# - numerical values **or**
# - counts
#
# Example of categorical data:
# - **gender**
# - **day**
# - **smoker**
# - **type**
#
# ---
#
# ## Why do we use a Categorical Plot?
# We use categorical plots to:
# - **Compare categories**
# - See **differences between groups**
# - Analyze **patterns across categories**
#
# In AI/ML:
# Categorical plots help understand **how categories affect numerical values**.
#
# ---
#
# ## Types of Categorical Plots in Seaborn
# - **barplot**
# - **countplot**
# - **boxplot**
# - **violinplot**
# - **stripplot**
# - **swarmplot**
# - **pointplot**
#
# ---

# %% [markdown]
# # Countplot

# %%
sns.countplot(df['sex'])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
# if you want to make it x axis

sns.countplot(x = df['sex'])
plt.show()

# %% [markdown]
# ## Lets check how many males are smoking and how many females are smoking

# %%
sns.countplot(x = df['sex'], hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # Bar plot

# %%
sns.barplot(x = df['sex'], y=df['total_bill'])
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x = df['sex'], y=df['total_bill'], estimator=np.sum)
plt.title('Total bill')
# Out:
# Text(0.5, 1.0, 'Total bill')

# %%
sns.barplot(x=df['sex'], y=df['tip'], estimator=np.sum)
plt.title('Tips')
# Out:
# Text(0.5, 1.0, 'Tips')

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x=df['tip'], y=df['day'], palette='rainbow')
plt.show()
# Out:
# C:\Users\Bulbul\AppData\Local\Temp\ipykernel_24144\1513173351.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['tip'], y=df['day'], palette='rainbow')

# %% [markdown]
# ## Boxplot and Violinplot
#
# Boxplot and violinplot help us understand how data is spread for different categories.
#
# **Boxplot**
#
# Shows minimum, maximum, median, and quartiles
#
# Helps compare values between groups
#
# Outliers are shown as separate points
#
# **In short:**
# 👉 Boxplot shows summary of data using boxes and lines.
#
# ---
#
# **Violinplot**
#
# Shows the shape of the data distribution
#
# Wider parts mean more data values there
#
# Combines boxplot + distribution view
#
# **In short:**
# 👉 Violinplot shows how data is spread and where values are concentrated.
#
# ---
#
# **When to use**
#
# Use **boxplot** when you want quick comparison
#
# Use **violinplot** when you want to see data distribution clearly

# %%
sns.violinplot(x = df['day'], y=df['total_bill'])
plt.show()

# %% [markdown]
# ## Stripplot and Swarmplot (Easy)
#
# **Stripplot**
#
# Shows each data point as a dot
#
# One axis is category, the other is value
#
# Points can overlap
#
# **In short:**
# 👉 Stripplot shows all data points, but they may overlap.
#
# ---
#
# **Swarmplot**
#
# Same as stripplot, but points do not overlap
#
# Dots are adjusted sideways for clarity
#
# Shows data distribution more clearly
#
# **In short:**
# 👉 Swarmplot spreads points so we can see them clearly.
#
# ---
#
# **Difference**:
#
# **Stripplot**→ simple, fast, overlaps allowed
#
# **Swarmplot** → clearer, no overlap, slower for large data

# %% [markdown]
# ### Strip Plot

# %%
sns.stripplot(x = 'day', y='total_bill', data=df)
plt.show()

# %% [markdown]
# ### Swarm Plot

# %%
sns.swarmplot(x= 'day', y='total_bill', data=df)
plt.show()

# %% [markdown]
# # How do we combine and Violin Plot and Swarm Plot

# %%
sns.violinplot(x='tip', y='day', data=df)
sns.swarmplot(x='tip', y='day', data=df)
# Out:
# c:\Users\Bulbul\Desktop\python-data-visualization\myenv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Bulbul\Desktop\python-data-visualization\myenv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='tip', ylabel='day'>
# c:\Users\Bulbul\Desktop\python-data-visualization\myenv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

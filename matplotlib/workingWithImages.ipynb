# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import matplotlib.image as mpimage

# %%
img = mpimage.imread('../img.png')

img
# Out:
# array([[[0.01568628, 0.01960784, 0.03137255],
#         [0.01176471, 0.01960784, 0.03137255],
#         [0.01568628, 0.01960784, 0.03529412],
#         ...,
#         [0.02745098, 0.02745098, 0.03921569],
#         [0.03137255, 0.02745098, 0.04313726],
#         [0.03529412, 0.03137255, 0.04313726]],
#
#        [[0.01176471, 0.01568628, 0.02745098],
#         [0.01176471, 0.01568628, 0.03137255],
#         [0.01568628, 0.01960784, 0.03529412],
#         ...,
#         [0.02352941, 0.01960784, 0.03529412],
#         [0.02352941, 0.01960784, 0.03529412],
#         [0.02352941, 0.01960784, 0.03137255]],
#
#        [[0.01568628, 0.01568628, 0.03137255],
#         [0.01176471, 0.01568628, 0.03137255],
#         [0.01568628, 0.01960784, 0.03529412],
#         ...,
#         [0.01960784, 0.01960784, 0.03529412],
#         [0.02352941, 0.02352941, 0.03529412],
#         [0.02745098, 0.02352941, 0.03921569]],
#
#        ...,
#
#        [[0.02745098, 0.02745098, 0.03921569],
# ...

# %%
img = mpimage.imread('../img.png')


plt.imshow(img)

# %%
# If we want to remove the axis

plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1023.5), np.float64(1535.5), np.float64(-0.5))

# %%
# How to crop

cropped_img =  img[60:500,100:300] # Crop rows 50-200, cols 100-300

plt.imshow(cropped_img)
plt.axis("off")  # optional
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(439.5), np.float64(-0.5))

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
y = x**2

plt.plot(x,y)

# %% [markdown]
# # Scatter Plot

# %%
plt.scatter(x,y)

# %% [markdown]
# # Histogram

# %%
from random import sample
data = sample(range(1,1000), 100)
data
plt.hist(data)
# Out:
# (array([13., 10., 12.,  9.,  8.,  9., 15.,  8.,  9.,  7.]),
#  array([ 11. , 109.3, 207.6, 305.9, 404.2, 502.5, 600.8, 699.1, 797.4,
#         895.7, 994. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Box plot

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x235693cac90>,
#   <matplotlib.lines.Line2D at 0x235693caf90>],
#  'caps': [<matplotlib.lines.Line2D at 0x235693cb2c0>,
#   <matplotlib.lines.Line2D at 0x235693cb590>],
#  'boxes': [<matplotlib.lines.Line2D at 0x235693ca9c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x235693cb890>],
#  'fliers': [<matplotlib.lines.Line2D at 0x235693cbbc0>],
#  'means': []}

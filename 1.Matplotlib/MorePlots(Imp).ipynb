# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# # Distribution Plot

# %% [markdown]
# We use **distribution plots** to visualize the distribution of **quantitative data**.
#
# The following plots are commonly used to visualize the distribution of a dataset:
#
# - **distplot / histplot**
# - **jointplot**
# - **pairplot**
# - **rugplot**
